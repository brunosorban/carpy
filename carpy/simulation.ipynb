# %%
import numpy as np
from Driver import Driver
from Function import Function
from Race import Race
from TMEasy import Tire
from Vehicle import Vehicle
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.9.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# %load_ext autoreload
# %autoreload 2

# %%
radius = 0.293
Jz_tire = 1
cz = 190000
dfx0 = 100000
dfy0 = 80000
fxm = 3900
fym = 3650
sxm = 0.11
sym = 0.16
fxs = 3600
fys = 3600
sxs = 0.4
sys = 0.5
n2L0 = 0.18
sy0 = 0.19
syE = 0.35
lamb = 2/3
TMEasy = Tire(radius, Jz_tire, cz, dfx0, dfy0, fxm, fym, sxm, sym, fxs, fys, sxs, sys, sy0, syE, lamb, n2L0)

# %%
driver = Driver(delta_1_control='steering', delta_2_control='steering', delta_3_control=None, delta_4_control=None)
# driver = Driver()

# %%
vehicle_mass = 1742
Izz = 2617
lf = 1.07
lr = 1.605
wf = 0
wr = 0

car = Vehicle(TMEasy, vehicle_mass, Izz, lf, lr, wf, wr)
print(car)

# %%
sim = Race(car, driver, maxTime=30, rtol=1e-2, atol=1e-2, maxStep=1e-2)
# Out:
# Solution Finished

# %%
sim.post_process()

# %%
sim.T1.comparaNPlots2([sim.T2, sim.T3, sim.T4])

# %%
sim.x.plot2D2()

# %%
sim.xy.plotparametric()

# %%
sim.animate(10)
