# %%
import numpy as np
from Driver import Driver
from Function import Function
from Race import Race
from TMEasy import Tire
from Vehicle import Vehicle

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
radius = 0.293
Jz_tire = 1
cz = 190000
dfx0 = 100000
dfy0 = 80000
fxm = 3900
fym = 3650
sxm = 0.11
sym = 0.16
fxs = 3600
fys = 3600
sxs = 0.4
sys = 0.5
n2L0 = 0.18
sy0 = 0.19
syE = 0.35
lamb = 2/3
frr = 0.015
TMEasy = Tire(radius, Jz_tire, cz, dfx0, dfy0, fxm, fym, sxm, sym, fxs, fys, sxs, sys, sy0, syE, lamb, n2L0, frr)

# %%
# driver = Driver(delta_1_control='steering', delta_2_control='steering', delta_3_control=None, delta_4_control=None)
driver = Driver(delta_1_control='S', delta_2_control='S', delta_3_control=None, delta_4_control=None)

# driver = Driver()

# %%
vehicle_mass = 1742
Izz = 2617
lf = 1.07
lr = 1.605
wf = 1.517
wr = 1.505
af = 2.17
cd = 0.3

car = Vehicle(TMEasy, vehicle_mass, Izz, lf, lr, wf, wr, af, cd)
print(car)

# %%
sim = Race(car, driver, maxTime=100, rtol=1e-3, atol=1e-3, maxStep=1e-2)
# Out:
# Solution Finished

# %%
sim.post_process()

# %%
sim.T1.comparaNPlots2([sim.T2, sim.T3, sim.T4])

# %%
sim.Trr.plot2D2()

# %%
sim.xy.plotparametric()

# %%
sim.animate(70)
