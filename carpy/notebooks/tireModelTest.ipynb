# %%
import sys
sys.path.append('../')
from Function import Function
from TMEasy import Tire

# %%
radius = 0.293
mass = 12
Jz_tire = 1
cz = 190000
dfx0 = 100000
dfy0 = 80000
fxm = 3900
fym = 3650
sxm = 0.11
sym = 0.16
fxs = 3600
fys = 3600
sxs = 0.4
sys = 0.5
n2L0 = 0.18
sy0 = 0.19
syE = 0.35
lamb = 2/3
frr = 0.015
TMEasy = Tire(radius, mass, Jz_tire, cz, dfx0, dfy0, fxm, fym, sxm, sym, fxs, fys, sxs, sys, sy0, syE, lamb, n2L0, frr)
TMEasy.all_info(camber_slip=0.0)
# Out:
# Vertical force considered: 3500N
# Camber slip = 0.00
# Bore slip = 0.00
# Coenering stiffness = 1186.9N/৹

# %%
TMEasy.all_info(camber_slip=0.01)
# Out:
# Vertical force considered: 3500N
# Camber slip = 0.01
# Bore slip = 0.00
# Coenering stiffness = 1193.0N/৹
